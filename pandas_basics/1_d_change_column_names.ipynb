# %% [raw]
# Change column names in dataframe

# %%
import pandas as pd
df = pd.DataFrame([['AA', 1, 'a'],['BB', 2, 'a'],['CC', 3, 'a']], columns = ['name','value','svalue'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   value   3 non-null      int64
#  2   svalue  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df.columns.values[1:] = ['new_' + val for val in df.columns.values[1:]]

# %%
df.columns.values
# Out:
# array(['name', 'new_value', 'new_svalue'], dtype=object)

# %%
df
# Out:
#   name  new_value new_svalue
# 0   AA          1          a
# 1   BB          2          a
# 2   CC          3          a
